# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

hf_ds = kagglehub.dataset_load(
    KaggleDatasetAdapter.HUGGING_FACE,
    "shengkunwang/housets-dataset",
    "*",
)

print(hf_ds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 import kagglehub
#       2 from kagglehub import KaggleDatasetAdapter
# ----> 4 hf_ds = kagglehub.dataset_load(
#       5     KaggleDatasetAdapter.HUGGING_FACE,
#       6     "shengkunwang/housets-dataset",
#       7     "*",
#       8 )
#      10 print(hf_ds)
#
# File d:\ml-aws\.venv\Lib\site-packages\kagglehub\datasets.py:145, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs, polars_frame_type, polars_kwargs)
#     142 if adapter is KaggleDatasetAdapter.HUGGING_FACE:
#     143     import kagglehub.hf_datasets  # noqa: PLC0415
# --> 145     return kagglehub.hf_datasets.load_hf_dataset(
#     146         handle,
#     147         path,
#     148         pandas_kwargs=pandas_kwargs,
#     149         sql_query=sql_query,
#     150         hf_kwargs=hf_kwargs,
#     151     )
# ...

# %%
import kagglehub
print(kagglehub.dataset_list_files("shengkunwang/housets-dataset"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 import kagglehub
# ----> 2 print(kagglehub.dataset_list_files("shengkunwang/housets-dataset"))
#
# AttributeError: module 'kagglehub' has no attribute 'dataset_list_files'
